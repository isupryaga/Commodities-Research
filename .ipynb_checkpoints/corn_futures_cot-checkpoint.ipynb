# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# Load COT
cot = pd.read_csv('cot_clean.csv', parse_dates=['date', 'tradeable_date'])

# Load EOD price data
tickers = {'corn': 'ZS=F', 'soy': 'ZC=F', 'hogs': 'HE=F', 'crude': 'CL=F','live_cattle': 'LE=F','feeder_cattle': 'GF=F'}
eod = {}
for name, ticker in tickers.items():
    df = yf.download(ticker, start='2000-01-01', auto_adjust=True)
    df.columns = ['_'.join(col).strip('_') for col in df.columns]
    eod[name] = df
    print(f"{name}: {len(df)} rows")

# Load intraday hourly
intraday = {}
for name, ticker in tickers.items():
    df = yf.download(ticker, interval='1h', period='2y', auto_adjust=True)
    df.columns = ['_'.join(col).strip('_') for col in df.columns]
    intraday[name] = df
    print(f"{name} 1h: {len(df)} rows")
# Out:
# [*********************100%***********************]  1 of 1 completed
# corn: 6411 rows
# [*********************100%***********************]  1 of 1 completed
# soy: 6419 rows
# [*********************100%***********************]  1 of 1 completed
# hogs: 6342 rows
# [*********************100%***********************]  1 of 1 completed
# crude: 6416 rows
# [*********************100%***********************]  1 of 1 completed
# live_cattle: 6274 rows
# [*********************100%***********************]  1 of 1 completed
# feeder_cattle: 6244 rows
# [*********************100%***********************]  1 of 1 completed
# corn 1h: 9283 rows
# [*********************100%***********************]  1 of 1 completed
# soy 1h: 9281 rows
# [*********************100%***********************]  1 of 1 completed
# hogs 1h: 2989 rows
# [*********************100%***********************]  1 of 1 completed
# crude 1h: 11232 rows
# [*********************100%***********************]  1 of 1 completed
# live_cattle 1h: 2991 rows
# [*********************100%***********************]  1 of 1 completed
# feeder_cattle 1h: 2976 rows

# %%
cot_market_map = {
    'CORN - CHICAGO BOARD OF TRADE': ('corn', 'ZS=F'),
    'SOYBEANS - CHICAGO BOARD OF TRADE': ('soy', 'ZC=F'),
    'LEAN HOGS - CHICAGO MERCANTILE EXCHANGE': ('hogs', 'HE=F'),
    'CRUDE OIL, LIGHT SWEET - NEW YORK MERCANTILE EXCHANGE': ('crude', 'CL=F'),
    'LIVE CATTLE - CHICAGO MERCANTILE EXCHANGE': ('live_cattle', 'LE=F'),
    'FEEDER CATTLE - CHICAGO MERCANTILE EXCHANGE': ('feeder_cattle', 'GF=F')
}

merged_1h = {}
for cot_name, (short_name, ticker) in cot_market_map.items():
    cot_market = cot[cot['Market and Exchange Names'] == cot_name][
        ['tradeable_date', 'cot_idx', 'spec_idx', 'oi_idx']
    ].copy()
    cot_market['tradeable_date'] = cot_market['tradeable_date'].astype('datetime64[s]')
    
    price = intraday[short_name].copy().reset_index()
    price.rename(columns={price.columns[0]: 'Datetime'}, inplace=True)
    price['Datetime'] = price['Datetime'].dt.tz_localize(None).astype('datetime64[s]')
    
    merged_1h[short_name] = pd.merge_asof(
        price.sort_values('Datetime'),
        cot_market.sort_values('tradeable_date'),
        left_on='Datetime',
        right_on='tradeable_date',
        direction='backward'
    ).set_index('Datetime')

for name, df in merged_1h.items():
    print(f"{name}: {len(df)} rows, cot_idx NaN: {df['cot_idx'].isna().sum()}")
# Out:
# corn: 9283 rows, cot_idx NaN: 0
# soy: 9281 rows, cot_idx NaN: 0
# hogs: 2989 rows, cot_idx NaN: 0
# crude: 11232 rows, cot_idx NaN: 0
# live_cattle: 2991 rows, cot_idx NaN: 0
# feeder_cattle: 2976 rows, cot_idx NaN: 0

# %%
for name in ['corn', 'soy', 'hogs', 'crude', 'live_cattle', 'feeder_cattle']:
    ticker = {'corn': 'ZS=F', 'soy': 'ZC=F', 'hogs': 'HE=F', 'crude': 'CL=F', 'live_cattle': 'LE=F', 'feeder_cattle': 'GF=F'}[name]
    d = merged_1h[name].copy()
    
    d['ret'] = d[f'Close_{ticker}'].pct_change()
    d['date'] = d.index.date
    d['hour'] = d.index.hour
    d['signal'] = (d['cot_idx'] > 0.8).astype(int)
    
    # For each day, compute: open-to-close return, and max adverse excursion
    daily = d.groupby('date').agg(
        signal=('signal', 'first'),
        open=(f'Open_{ticker}', 'first'),
        close=(f'Close_{ticker}', 'last'),
        high=(f'High_{ticker}', 'max'),
        low=(f'Low_{ticker}', 'min'),
    )
    daily['oc_ret'] = (daily['close'] - daily['open']) / daily['open']
    daily['range'] = (daily['high'] - daily['low']) / daily['open']
    daily['up_move'] = (daily['high'] - daily['open']) / daily['open']
    daily['down_move'] = (daily['open'] - daily['low']) / daily['open']
    
    on = daily[daily['signal'] == 1]
    off = daily[daily['signal'] == 0]
    
    print(f"\n{'='*40}")
    print(f"{name.upper()}")
    print(f"{'Metric':<20} {'Signal':>10} {'No Signal':>10}")
    print(f"{'OC return':<20} {on['oc_ret'].mean():>10.5f} {off['oc_ret'].mean():>10.5f}")
    print(f"{'Up move from open':<20} {on['up_move'].mean():>10.5f} {off['up_move'].mean():>10.5f}")
    print(f"{'Down move from open':<20} {on['down_move'].mean():>10.5f} {off['down_move'].mean():>10.5f}")
    print(f"{'Daily range':<20} {on['range'].mean():>10.5f} {off['range'].mean():>10.5f}")
    print(f"{'Win rate':<20} {(on['oc_ret']>0).mean():>10.2%} {(off['oc_ret']>0).mean():>10.2%}")
# Out:
# ========================================
# CORN
# Metric                   Signal  No Signal
# OC return               0.00087    0.00029
# Up move from open       0.00819    0.00979
# Down move from open     0.00688    0.00852
# Daily range             0.01508    0.01831
# Win rate                 52.03%     51.72%
#
# ========================================
# SOY
# Metric                   Signal  No Signal
# OC return               0.00162    0.00017
# Up move from open       0.01052    0.01110
# Down move from open     0.00815    0.01068
# Daily range             0.01867    0.02177
# Win rate                 50.00%     50.25%
#
# ========================================
# HOGS
# Metric                   Signal  No Signal
# OC return               0.00153    0.00577
# Up move from open       0.01320    0.01874
# Down move from open     0.01059    0.01252
# Daily range             0.02378    0.03126
# Win rate                 59.09%     53.90%
#
# ========================================
# CRUDE
# Metric                   Signal  No Signal
# OC return              -0.00042    0.00029
# Up move from open       0.01249    0.01339
# Down move from open     0.01297    0.01363
# Daily range             0.02546    0.02702
# Win rate                 50.94%     49.56%
#
# ========================================
# LIVE_CATTLE
# Metric                   Signal  No Signal
# OC return               0.00163   -0.00054
# Up move from open       0.00878    0.00785
# Down move from open     0.00703    0.00846
# Daily range             0.01581    0.01631
# Win rate                 54.07%     47.96%
#
# ========================================
# FEEDER_CATTLE
# Metric                   Signal  No Signal
# OC return               0.00608    0.00014
# Up move from open       0.01294    0.00955
# Down move from open     0.00743    0.00976
# Daily range             0.02037    0.01931
# Win rate                 53.69%     53.51%

# %%
for name in ['corn', 'soy', 'hogs', 'crude', 'live_cattle', 'feeder_cattle']:
    ticker = {'corn': 'ZS=F', 'soy': 'ZC=F', 'hogs': 'HE=F', 'crude': 'CL=F', 'live_cattle': 'LE=F', 'feeder_cattle': 'GF=F'}[name]
    d = merged_1h[name].copy()
    d.index = pd.to_datetime(d.index)
    
    d['date'] = d.index.date
    d['hour'] = d.index.hour
    d['signal'] = (d['cot_idx'] > 0.8).astype(int)
    
    daily_open = d[d['hour'] == 14].groupby('date')[f'Open_{ticker}'].first()
    daily_close = d.groupby('date')[f'Close_{ticker}'].last()
    daily_signal = d.groupby('date')['signal'].first()
    first3_low = d[d['hour'].isin([14, 15, 16])].groupby('date')[f'Low_{ticker}'].min()
    first3_high = d[d['hour'].isin([14, 15, 16])].groupby('date')[f'High_{ticker}'].max()
    
    daily = pd.DataFrame({
        'open': daily_open,
        'close': daily_close,
        'signal': daily_signal,
        'first3_low': first3_low,
        'first3_high': first3_high,
    }).dropna()
    
    daily['pullback'] = (daily['open'] - daily['first3_low']) / daily['open']
    daily['breakout'] = (daily['first3_high'] - daily['open']) / daily['open']
    daily['oc_ret'] = (daily['close'] - daily['open']) / daily['open']
    
    on = daily[daily['signal'] == 1]
    off = daily[daily['signal'] == 0]
    
    print(f"\n{'='*40}")
    print(f"{name.upper()}")
    print(f"{'Metric':<25} {'Signal':>10} {'No Signal':>10}")
    print(f"{'Avg pullback from open':<25} {on['pullback'].mean():>10.5f} {off['pullback'].mean():>10.5f}")
    print(f"{'Avg breakout from open':<25} {on['breakout'].mean():>10.5f} {off['breakout'].mean():>10.5f}")
    print(f"{'Days price pulled back':<25} {(on['pullback']>0.001).mean():>10.2%} {(off['pullback']>0.001).mean():>10.2%}")
    print(f"{'OC return':<25} {on['oc_ret'].mean():>10.5f} {off['oc_ret'].mean():>10.5f}")
# Out:
# ========================================
# CORN
# Metric                        Signal  No Signal
# Avg pullback from open       0.00401    0.00604
# Avg breakout from open       0.00518    0.00577
# Days price pulled back        83.74%     87.04%
# OC return                    0.00094   -0.00041
#
# ========================================
# SOY
# Metric                        Signal  No Signal
# Avg pullback from open       0.00567    0.00764
# Avg breakout from open       0.00616    0.00794
# Days price pulled back        88.78%     90.32%
# OC return                    0.00015    0.00023
#
# ========================================
# HOGS
# Metric                        Signal  No Signal
# Avg pullback from open       0.00636    0.01012
# Avg breakout from open       0.01007    0.01471
# Days price pulled back        75.76%     85.94%
# OC return                    0.00040    0.00575
#
# ========================================
# CRUDE
# Metric                        Signal  No Signal
# Avg pullback from open       0.00865    0.00858
# Avg breakout from open       0.00779    0.00781
# Days price pulled back        88.37%     90.93%
# OC return                   -0.00078    0.00033
#
# ========================================
# LIVE_CATTLE
# Metric                        Signal  No Signal
# Avg pullback from open       0.00633    0.00600
# Avg breakout from open       0.00768    0.00719
# Days price pulled back        82.09%     85.83%
# OC return                    0.00161    0.00033
#
# ========================================
# FEEDER_CATTLE
# Metric                        Signal  No Signal
# Avg pullback from open       0.00571    0.00775
# Avg breakout from open       0.01037    0.00808
# Days price pulled back        81.54%     84.95%
# OC return                    0.00520    0.00051

# %%
rows = []

for name, df in eod.items():

    close = df.filter(like="Close").iloc[:,0]
    high  = df.filter(like="High").iloc[:,0]
    low   = df.filter(like="Low").iloc[:,0]

    returns = close.pct_change().dropna()
    ranges = (high - low) / close

    rows.append({
        "market": name,
        "volatility": returns.std(),
        "avg_abs_return": returns.abs().mean(),
        "avg_range": ranges.mean()
    })

table = pd.DataFrame(rows)
print(table.round(4))
# Out:
#           market  volatility  avg_abs_return  avg_range
# 0           corn      0.0157          0.0110     0.0162
# 1            soy      0.0178          0.0127     0.0197
# 2           hogs      0.0233          0.0131     0.0161
# 3          crude      0.0489          0.0184     0.0338
# 4    live_cattle      0.0113          0.0076     0.0102
# 5  feeder_cattle      0.0105          0.0069     0.0095

# %%
for name, df in eod.items():

    close = df.filter(like="Close").iloc[:,0]
    high  = df.filter(like="High").iloc[:,0]
    low   = df.filter(like="Low").iloc[:,0]

    tmp = pd.DataFrame(index=df.index)
    tmp["ret"] = close.pct_change()
    tmp["day"] = tmp.index.day_name()
    tmp["rng"] = (high - low) / close

    returns = tmp.groupby("day")["ret"].mean()
    stats = tmp.groupby("day")["ret"].std()

    print(name)
    print("RETURNS:")
    print(returns)
    print("VOLATILITY:")
    print(stats)
# Out:
# corn
# RETURNS:
# day
# Friday       0.000312
# Monday      -0.000523
# Thursday     0.000284
# Tuesday      0.000606
# Wednesday    0.000583
# Name: ret, dtype: float64
# VOLATILITY:
# day
# Friday       0.016559
# Monday       0.018439
# Thursday     0.014939
# Tuesday      0.015006
# Wednesday    0.013475
# Name: ret, dtype: float64
# soy
# RETURNS:
# day
# Friday       0.000435
# Monday       0.000152
# Thursday     0.000325
# Tuesday     -0.000047
# Wednesday    0.000667
# Name: ret, dtype: float64
# VOLATILITY:
# day
# Friday       0.017440
# Monday       0.020560
# Thursday     0.017286
# Tuesday      0.017500
# Wednesday    0.016119
# Name: ret, dtype: float64
# hogs
# RETURNS:
# day
# Friday       0.000620
# Monday      -0.000860
# Thursday     0.000345
# Tuesday      0.000679
# Wednesday    0.000981
# Name: ret, dtype: float64
# VOLATILITY:
# day
# Friday       0.020962
# Monday       0.028170
# Thursday     0.023244
# Tuesday      0.024512
# Wednesday    0.019107
# Name: ret, dtype: float64
# crude
# RETURNS:
# day
# Friday       0.001786
# Monday      -0.003436
# Thursday     0.001312
# Tuesday     -0.001227
# Wednesday    0.001009
# Name: ret, dtype: float64
# VOLATILITY:
# day
# Friday       0.023152
# Monday       0.092302
# Thursday     0.026708
# Tuesday      0.042132
# Wednesday    0.028922
# Name: ret, dtype: float64
# live_cattle
# RETURNS:
# day
# Friday       0.000184
# Monday      -0.000501
# Thursday     0.000084
# Tuesday      0.000710
# Wednesday    0.000639
# Name: ret, dtype: float64
# VOLATILITY:
# day
# Friday       0.011263
# Monday       0.012302
# Thursday     0.010781
# Tuesday      0.011142
# Wednesday    0.011155
# Name: ret, dtype: float64
# feeder_cattle
# RETURNS:
# day
# Friday       0.000332
# Monday      -0.000060
# Thursday     0.000053
# Tuesday      0.000845
# Wednesday    0.000162
# Name: ret, dtype: float64
# VOLATILITY:
# day
# Friday       0.014186
# Monday       0.011064
# Thursday     0.008490
# Tuesday      0.009266
# Wednesday    0.008527
# Name: ret, dtype: float64

# %%
cot_market_map = {
    'CORN - CHICAGO BOARD OF TRADE': ('corn', 'ZS=F'),
    'SOYBEANS - CHICAGO BOARD OF TRADE': ('soy', 'ZC=F'),
    'LEAN HOGS - CHICAGO MERCANTILE EXCHANGE': ('hogs', 'HE=F'),
    'CRUDE OIL, LIGHT SWEET - NEW YORK MERCANTILE EXCHANGE': ('crude', 'CL=F'),
    'LIVE CATTLE - CHICAGO MERCANTILE EXCHANGE': ('live_cattle', 'LE=F'),
    'FEEDER CATTLE - CHICAGO MERCANTILE EXCHANGE': ('feeder_cattle', 'GF=F')
}

for cot_name, (short, ticker) in cot_market_map.items():

    price = eod[short].copy()
    if isinstance(price.columns, pd.MultiIndex):
        price.columns = ['_'.join(col).strip('_') for col in price.columns]

    close_col = [c for c in price.columns if "Close" in c][0]
    open_col  = [c for c in price.columns if "Open" in c][0]

    price["oc_ret"] = (price[close_col] - price[open_col]) / price[open_col]

    cot_mkt = cot[cot["Market and Exchange Names"] == cot_name][
        ["tradeable_date", "cot_idx"]
    ].copy()
    
    price = price.reset_index()
    price["Date"] = price["Date"].astype("datetime64[s]")

    cot_mkt["tradeable_date"] = cot_mkt["tradeable_date"].astype("datetime64[s]")
    
    merged = pd.merge_asof(
        price.reset_index().sort_values("Date"),
        cot_mkt.sort_values("tradeable_date"),
        left_on="Date",
        right_on="tradeable_date",
        direction="backward"
    ).set_index("Date")

    mask = (merged.index >= "2008-01-01") & (merged[close_col] != merged[open_col])
    merged = merged[mask].dropna(subset=["cot_idx"])

    merged["signal"] = (merged["cot_idx"] > 0.8).astype(int).shift(1)

    on = merged[merged["signal"] == 1]["oc_ret"]

    print("="*40)
    print(short.upper())
    print(f"Direct test - on-signal mean: {on.mean():.5f}")
    print(f"Signal days/yr: {len(on)/17:.0f}")
# Out:
# ========================================
# CORN
# Direct test - on-signal mean: 0.00053
# Signal days/yr: 83
# ========================================
# SOY
# Direct test - on-signal mean: 0.00039
# Signal days/yr: 70
# ========================================
# HOGS
# Direct test - on-signal mean: -0.00089
# Signal days/yr: 60
# ========================================
# CRUDE
# Direct test - on-signal mean: -0.00387
# Signal days/yr: 89
# ========================================
# LIVE_CATTLE
# Direct test - on-signal mean: -0.00016
# Signal days/yr: 67
# ========================================
# FEEDER_CATTLE
# Direct test - on-signal mean: 0.00000
# Signal days/yr: 65

# %%
cot_market_map = {
    'CORN - CHICAGO BOARD OF TRADE': ('corn', 'ZS=F'),
    'SOYBEANS - CHICAGO BOARD OF TRADE': ('soy', 'ZC=F'),
    'LEAN HOGS - CHICAGO MERCANTILE EXCHANGE': ('hogs', 'HE=F'),
    'CRUDE OIL, LIGHT SWEET - NEW YORK MERCANTILE EXCHANGE': ('crude', 'CL=F'),
    'LIVE CATTLE - CHICAGO MERCANTILE EXCHANGE': ('live_cattle', 'LE=F'),
    'FEEDER CATTLE - CHICAGO MERCANTILE EXCHANGE': ('feeder_cattle', 'GF=F')
}

for cot_name, (short, ticker) in cot_market_map.items():

    price = eod[short].copy()

    if isinstance(price.columns, pd.MultiIndex):
        price.columns = ['_'.join(col).strip('_') for col in price.columns]

    close_col = next(c for c in price.columns if "Close" in c)
    open_col  = next(c for c in price.columns if "Open" in c)

    price["ret"] = price[close_col].pct_change()
    price["oc_ret"] = (price[close_col] - price[open_col]) / price[open_col]

    cot_mkt = cot[cot["Market and Exchange Names"] == cot_name][
        ["tradeable_date", "cot_idx"]
    ].copy()

    price = price.reset_index()
    price["Date"] = price["Date"].astype("datetime64[s]")
    cot_mkt["tradeable_date"] = cot_mkt["tradeable_date"].astype("datetime64[s]")

    merged = pd.merge_asof(
        price.sort_values("Date"),
        cot_mkt.sort_values("tradeable_date"),
        left_on="Date",
        right_on="tradeable_date",
        direction="backward"
    ).set_index("Date")

    merged = merged.dropna(subset=["cot_idx"])

    merged["overnight"] = merged["ret"] - merged["oc_ret"]
    merged["signal"] = (merged["cot_idx"] > 0.8).astype(int).shift(1)

    on = merged[merged["signal"] == 1]

    print("="*40)
    print(short.upper())
    print(f"Close-to-close on signal: {on['ret'].mean():.5f}")
    print(f"Open-to-close on signal:  {on['oc_ret'].mean():.5f}")
    print(f"Overnight on signal:      {on['overnight'].mean():.5f}")
# Out:
# ========================================
# CORN
# Close-to-close on signal: 0.00033
# Open-to-close on signal:  0.00072
# Overnight on signal:      -0.00039
# ========================================
# SOY
# Close-to-close on signal: -0.00001
# Open-to-close on signal:  0.00041
# Overnight on signal:      -0.00042
# ========================================
# HOGS
# Close-to-close on signal: 0.00133
# Open-to-close on signal:  -0.00077
# Overnight on signal:      0.00210
# ========================================
# CRUDE
# Close-to-close on signal: -0.00214
# Open-to-close on signal:  -0.00295
# Overnight on signal:      0.00081
# ========================================
# LIVE_CATTLE
# Close-to-close on signal: 0.00013
# Open-to-close on signal:  -0.00007
# Overnight on signal:      0.00021
# ========================================
# FEEDER_CATTLE
# Close-to-close on signal: 0.00030
# Open-to-close on signal:  0.00002
# Overnight on signal:      0.00028

# %%
market_map = {
    'CORN - CHICAGO BOARD OF TRADE': 'corn',
    'SOYBEANS - CHICAGO BOARD OF TRADE': 'soy',
    'LEAN HOGS - CHICAGO MERCANTILE EXCHANGE': 'hogs',
    'LIVE CATTLE - CHICAGO MERCANTILE EXCHANGE': 'live_cattle',
    'FEEDER CATTLE - CHICAGO MERCANTILE EXCHANGE': 'feeder_cattle'
}

merged = {}

for cot_name, short_name in market_map.items():

    cot_market = cot[cot['Market and Exchange Names'] == cot_name][
        ['tradeable_date', 'cot_idx', 'spec_idx', 'oi_idx', 'comm_change']
    ].copy()

    price = eod[short_name].copy()

    if isinstance(price.columns, pd.MultiIndex):
        price.columns = [c[0] for c in price.columns]

    price = price.reset_index()
    price["Date"] = price["Date"].astype("datetime64[s]")
    cot_market["tradeable_date"] = cot_market["tradeable_date"].astype("datetime64[s]")

    merged[short_name] = pd.merge_asof(
        price.sort_values('Date'),
        cot_market.sort_values('tradeable_date'),
        left_on='Date',
        right_on='tradeable_date',
        direction='backward'
    ).set_index('Date')

    close_col = next(c for c in merged[short_name].columns if "Close" in c)
    open_col  = next(c for c in merged[short_name].columns if "Open" in c)
    
    merged[short_name]['oc_ret'] = (
        (merged[short_name][close_col] - merged[short_name][open_col]) /
        merged[short_name][open_col]
    )
for name, df in merged.items():
    close_col = next(c for c in df.columns if "Close" in c)
    df["ret"] = df[close_col].pct_change()

for name in ['corn','soy','hogs', 'live_cattle', 'feeder_cattle']:

    d = merged[name].copy()
    d = d[d.index >= '2008-01-01'].dropna(subset=['cot_idx','spec_idx','oi_idx'])

    years = (d.index.max() - d.index.min()).days / 365

    print(f"\n{'='*50}")
    print(f"{name.upper()}")
    print(f"{'Signal':<30} {'On':>8} {'Off':>8} {'Days/yr':>8} {'WR':>8}")

    for label, signal in [
        ('COT only',         (d['cot_idx'] > 0.8)),
        ('COT + spec div',   (d['cot_idx'] > 0.8) & (d['spec_idx'] < 0.2)),
        ('COT + spec + OI',  (d['cot_idx'] > 0.8) & (d['spec_idx'] < 0.2) & (d['oi_idx'] > 0.5)),
    ]:

        sig = signal.astype(int).shift(1)

        on = d[sig == 1]['oc_ret']
        off = d[sig == 0]['oc_ret']

        print(f"{label:<30} {on.mean():>8.5f} {off.mean():>8.5f} {len(on)/years:>8.0f} {(on>0).mean():>8.2%}")
# Out:
# ==================================================
# CORN
# Signal                               On      Off  Days/yr       WR
# COT only                        0.00052  0.00014       79   51.75%
# COT + spec div                  0.00048  0.00017       71   51.40%
# COT + spec + OI                 0.00081  0.00020       24   53.50%
#
# ==================================================
# SOY
# Signal                               On      Off  Days/yr       WR
# COT only                        0.00038  0.00018       66   50.66%
# COT + spec div                  0.00023  0.00024       61   49.86%
# COT + spec + OI                 0.00058  0.00020       23   47.60%
#
# ==================================================
# HOGS
# Signal                               On      Off  Days/yr       WR
# COT only                       -0.00088 -0.00037       57   46.63%
# COT + spec div                 -0.00074 -0.00043       50   46.56%
# COT + spec + OI                 0.00021 -0.00053       13   48.29%
#
# ==================================================
# LIVE_CATTLE
# Signal                               On      Off  Days/yr       WR
# COT only                       -0.00017 -0.00019       63   50.04%
# COT + spec div                 -0.00025 -0.00016       58   49.57%
# COT + spec + OI                -0.00128 -0.00014        8   43.15%
#
# ==================================================
# FEEDER_CATTLE
# Signal                               On      Off  Days/yr       WR
# COT only                        0.00000 -0.00015       62   47.95%
# COT + spec div                  0.00005 -0.00015       49   48.48%
# COT + spec + OI                 0.00055 -0.00015       13   51.44%

# %%
for name, df in eod.items():

    tmp = df.copy()

    # flatten only if multiindex
    if isinstance(tmp.columns, pd.MultiIndex):
        tmp.columns = ['_'.join(c).strip('_') for c in tmp.columns]

    close_col = next(c for c in tmp.columns if "Close" in c)

    r = tmp[close_col].pct_change().dropna()

    print(name)
    print("mean:", r.mean())
    print("std:", r.std())
    print("skew:", r.skew())
    print("kurtosis:", r.kurtosis())
    print()
# Out:
# corn
# mean: 0.00026606453134535334
# std: 0.01572102033199691
# skew: -0.5040906784564207
# kurtosis: 15.605133610871036
#
# soy
# mean: 0.000308679821704179
# std: 0.017789245964611688
# skew: -0.5138009791755556
# kurtosis: 10.083536468640894
#
# hogs
# mean: 0.00037333339933366894
# std: 0.02332454800087316
# skew: -0.06377063988358274
# kurtosis: 25.79302025691383
#
# crude
# mean: -6.788638972293343e-05
# std: 0.04885254173120241
# skew: -40.91018555566471
# kurtosis: 2470.0366983800877
#
# live_cattle
# mean: 0.00023670868253144266
# std: 0.011329451407913034
# skew: -0.7859228852933955
# kurtosis: 12.119811372770704
#
# feeder_cattle
# mean: 0.0002729000695932368
# std: 0.01050925563006585
# skew: 0.4096404657783935
# kurtosis: 12.839020680081239

# %%
for name, df in eod.items():

    tmp = df.copy()

    if isinstance(tmp.columns, pd.MultiIndex):
        tmp.columns = ['_'.join(c).strip('_') for c in tmp.columns]

    close_col = next(c for c in tmp.columns if "Close" in c)

    tmp["ret"] = tmp[close_col].pct_change()
    tmp["month"] = tmp.index.month

    stats = tmp.groupby("month")["ret"].std()

    print(name)
    print(stats)
    print()
# Out:
# corn
# month
# 1     0.014026
# 2     0.012171
# 3     0.014271
# 4     0.012608
# 5     0.014538
# 6     0.015806
# 7     0.020299
# 8     0.019860
# 9     0.021095
# 10    0.014540
# 11    0.013782
# 12    0.011570
# Name: ret, dtype: float64
#
# soy
# month
# 1     0.015483
# 2     0.012664
# 3     0.017041
# 4     0.015503
# 5     0.018184
# 6     0.020428
# 7     0.026687
# 8     0.016668
# 9     0.019708
# 10    0.017246
# 11    0.014316
# 12    0.014703
# Name: ret, dtype: float64
#
# hogs
# month
# 1     0.014613
# 2     0.024301
# 3     0.016959
# 4     0.033975
# 5     0.022187
# 6     0.016136
# 7     0.019784
# 8     0.035116
# 9     0.017390
# 10    0.027237
# 11    0.017389
# 12    0.021311
# Name: ret, dtype: float64
#
# crude
# month
# 1     0.024966
# 2     0.024333
# 3     0.034057
# 4     0.150264
# 5     0.023623
# 6     0.021639
# 7     0.019886
# 8     0.020748
# 9     0.025949
# 10    0.022040
# 11    0.025773
# 12    0.026239
# Name: ret, dtype: float64
#
# live_cattle
# month
# 1     0.009662
# 2     0.008534
# 3     0.012392
# 4     0.011640
# 5     0.015594
# 6     0.010873
# 7     0.011458
# 8     0.008668
# 9     0.011855
# 10    0.010191
# 11    0.012517
# 12    0.010394
# Name: ret, dtype: float64
#
# feeder_cattle
# month
# 1     0.009408
# 2     0.009928
# 3     0.010640
# 4     0.011570
# 5     0.014267
# 6     0.010286
# 7     0.009572
# 8     0.008796
# 9     0.009178
# 10    0.008294
# 11    0.012581
# 12    0.010100
# Name: ret, dtype: float64

# %%
def backtest_cot(df, long_thresh=0.8, short_thresh=0.2, silent=False):

    df = df.copy()

    if "ret" not in df.columns:
        close_col = next(c for c in df.columns if "Close" in c)
        df["ret"] = df[close_col].pct_change()

    df = df.dropna(subset=['cot_idx','ret'])

    df['signal'] = 0
    df.loc[df['cot_idx'] > long_thresh, 'signal'] = 1
    df.loc[df['cot_idx'] < short_thresh, 'signal'] = -1

    df['signal'] = df['signal'].shift(1)

    df['strat_ret'] = df['signal'] * df['ret']
    df['equity'] = (1 + df['strat_ret']).cumprod()

    total_ret = df['equity'].iloc[-1] - 1
    annual_ret = (1 + total_ret) ** (252 / len(df)) - 1

    std = df['strat_ret'].std()
    sharpe = 0 if std == 0 else df['strat_ret'].mean() / std * (252 ** 0.5)

    max_dd = (df['equity'] / df['equity'].cummax() - 1).min()

    trades = df[df['signal'] != 0]['strat_ret']
    win_rate = (trades > 0).mean() if len(trades) else 0
    n_trades = len(trades)

    metrics = dict(
        annual=annual_ret,
        sharpe=sharpe,
        max_dd=max_dd,
        win_rate=win_rate,
        n_days=n_trades
    )

    if not silent:
        for k,v in metrics.items():
            print(f"{k}: {v:.3f}")

    return df, metrics

# %%
def backtest_cot_sized(df, long_thresh=0.8, short_thresh=0.2, long_only=False,
                       target_vol=0.01, vol_window=20, silent=False):

    df = df.copy()

    if "ret" not in df.columns:
        close_col = next(c for c in df.columns if "Close" in c)
        df["ret"] = df[close_col].pct_change()

    df = df.dropna(subset=['cot_idx','ret'])

    df['signal'] = 0
    df.loc[df['cot_idx'] > long_thresh, 'signal'] = 1
    if not long_only:
        df.loc[df['cot_idx'] < short_thresh, 'signal'] = -1

    df['signal'] = df['signal'].shift(1)

    # realized volatility
    df['vol'] = df['ret'].rolling(vol_window).std()

    # avoid divide-by-zero
    df['vol'] = df['vol'].replace(0, np.nan)

    df['size'] = (target_vol / df['vol']).clip(0.1, 3.0)
    df['size'] = df['size'].shift(1)

    df = df.dropna(subset=['size'])

    df['strat_ret'] = df['signal'] * df['size'] * df['ret']
    df['equity'] = (1 + df['strat_ret']).cumprod()

    total_ret = df['equity'].iloc[-1] - 1
    annual_ret = (1 + total_ret) ** (252 / len(df)) - 1

    std = df['strat_ret'].std()
    sharpe = 0 if std == 0 else df['strat_ret'].mean() / std * (252 ** 0.5)

    max_dd = (df['equity'] / df['equity'].cummax() - 1).min()

    trades = df[df['signal'] != 0]['strat_ret']
    win_rate = (trades > 0).mean() if len(trades) else 0
    n_trades = len(trades)

    metrics = dict(
        annual=annual_ret,
        sharpe=sharpe,
        max_dd=max_dd,
        win_rate=win_rate,
        n_days=n_trades
    )

    if not silent:
        for k, v in metrics.items():
            print(f"{k}: {v:.3f}")

    return df, metrics

# %%
periods = {
    "2008-2012": ("2008-01-01", "2012-12-31"),
    "2013-2016": ("2013-01-01", "2016-12-31"),
    "2017-2020": ("2017-01-01", "2020-12-31"),
    "2021-2024": ("2021-01-01", "2024-12-31"),
}
print(f"\nLean Hogs:")
print(f"{'Period':<12} {'Annual':>8} {'Sharpe':>8} {'MaxDD':>8} {'WinRate':>8}")
for period_name, (start, end) in periods.items():
    mask = (merged['hogs'].index >= start) & (merged['hogs'].index <= end)
    period_df = merged['hogs'][mask].copy()
    _, m = backtest_cot_sized(period_df, long_only=True, silent=True)
    print(f"{period_name:<12} {m['annual']:>8.2%} {m['sharpe']:>8.3f} {m['max_dd']:>8.2%} {m['win_rate']:>8.2%}")
# Out:
# Lean Hogs:
# Period         Annual   Sharpe    MaxDD  WinRate
# 2008-2012      11.04%    0.657   -8.18%   47.27%
# 2013-2016       1.87%    0.225  -20.53%   54.58%
# 2017-2020       0.41%    0.096  -21.71%   47.24%
# 2021-2024       5.00%    0.387  -21.92%   46.21%

# %%
periods = {
    "2008-2012": ("2008-01-01", "2012-12-31"),
    "2013-2016": ("2013-01-01", "2016-12-31"),
    "2017-2020": ("2017-01-01", "2020-12-31"),
    "2021-2024": ("2021-01-01", "2024-12-31"),
}
print(f"\nCorn:")
print(f"{'Period':<12} {'Annual':>8} {'Sharpe':>8} {'MaxDD':>8} {'WinRate':>8}")
for period_name, (start, end) in periods.items():
    mask = (merged['corn'].index >= start) & (merged['corn'].index <= end)
    period_df = merged['corn'][mask].copy()
    _, m = backtest_cot_sized(period_df, long_only=True, silent=True)
    print(f"{period_name:<12} {m['annual']:>8.2%} {m['sharpe']:>8.3f} {m['max_dd']:>8.2%} {m['win_rate']:>8.2%}")
# Out:
# Corn:
# Period         Annual   Sharpe    MaxDD  WinRate
# 2008-2012       5.97%    0.618  -11.74%   55.06%
# 2013-2016       3.48%    0.376  -16.74%   52.71%
# 2017-2020       2.62%    0.329  -19.08%   48.41%
# 2021-2024      -7.10%   -0.651  -26.11%   49.39%

# %%
periods = {
    "2008-2012": ("2008-01-01", "2012-12-31"),
    "2013-2016": ("2013-01-01", "2016-12-31"),
    "2017-2020": ("2017-01-01", "2020-12-31"),
    "2021-2024": ("2021-01-01", "2024-12-31"),
}
print(f"\nSoybeans:")
print(f"{'Period':<12} {'Annual':>8} {'Sharpe':>8} {'MaxDD':>8} {'WinRate':>8}")
for period_name, (start, end) in periods.items():
    mask = (merged['soy'].index >= start) & (merged['soy'].index <= end)
    period_df = merged['soy'][mask].copy()
    _, m = backtest_cot_sized(period_df, long_only=True, silent=True)
    print(f"{period_name:<12} {m['annual']:>8.2%} {m['sharpe']:>8.3f} {m['max_dd']:>8.2%} {m['win_rate']:>8.2%}")
# Out:
# Soybeans:
# Period         Annual   Sharpe    MaxDD  WinRate
# 2008-2012      -1.44%   -0.136  -18.58%   49.22%
# 2013-2016      -4.92%   -0.353  -32.89%   50.00%
# 2017-2020       5.45%    0.640   -9.74%   55.65%
# 2021-2024       0.94%    0.142  -22.59%   46.94%

# %%
periods = {
    "2008-2012": ("2008-01-01", "2012-12-31"),
    "2013-2016": ("2013-01-01", "2016-12-31"),
    "2017-2020": ("2017-01-01", "2020-12-31"),
    "2021-2024": ("2021-01-01", "2024-12-31"),
}
print(f"\nLive Cattle:")
print(f"{'Period':<12} {'Annual':>8} {'Sharpe':>8} {'MaxDD':>8} {'WinRate':>8}")
for period_name, (start, end) in periods.items():
    mask = (merged['live_cattle'].index >= start) & (merged['live_cattle'].index <= end)
    period_df = merged['live_cattle'][mask].copy()
    _, m = backtest_cot_sized(period_df, long_only=True, silent=True)
    print(f"{period_name:<12} {m['annual']:>8.2%} {m['sharpe']:>8.3f} {m['max_dd']:>8.2%} {m['win_rate']:>8.2%}")
# Out:
# Live Cattle:
# Period         Annual   Sharpe    MaxDD  WinRate
# 2008-2012      -0.22%    0.022  -22.92%   49.71%
# 2013-2016      -2.22%   -0.214  -21.56%   48.65%
# 2017-2020      -2.30%   -0.113  -24.66%   50.76%
# 2021-2024       2.17%    0.307  -12.64%   53.62%

# %%
periods = {
    "2008-2012": ("2008-01-01", "2012-12-31"),
    "2013-2016": ("2013-01-01", "2016-12-31"),
    "2017-2020": ("2017-01-01", "2020-12-31"),
    "2021-2024": ("2021-01-01", "2024-12-31"),
}
print(f"\nFeeder Cattle:")
print(f"{'Period':<12} {'Annual':>8} {'Sharpe':>8} {'MaxDD':>8} {'WinRate':>8}")
for period_name, (start, end) in periods.items():
    mask = (merged['feeder_cattle'].index >= start) & (merged['feeder_cattle'].index <= end)
    period_df = merged['feeder_cattle'][mask].copy()
    _, m = backtest_cot_sized(period_df, long_only=True, silent=True)
    print(f"{period_name:<12} {m['annual']:>8.2%} {m['sharpe']:>8.3f} {m['max_dd']:>8.2%} {m['win_rate']:>8.2%}")
# Out:
# Feeder Cattle:
# Period         Annual   Sharpe    MaxDD  WinRate
# 2008-2012       2.65%    0.370  -13.69%   52.13%
# 2013-2016      -1.40%   -0.049  -32.36%   47.20%
# 2017-2020       1.53%    0.217  -14.21%   47.52%
# 2021-2024       8.38%    0.794  -13.28%   48.36%

# %%
markets = ['hogs', 'live_cattle', 'feeder_cattle']

periods = {
    "2008-2012": ("2008-01-01", "2012-12-31"),
    "2013-2016": ("2013-01-01", "2016-12-31"),
    "2017-2020": ("2017-01-01", "2020-12-31"),
    "2021-2024": ("2021-01-01", "2024-12-31"),
}

for m in markets:
    print(f"\n{'='*40}\n{m.upper()}")
    
    for name, (start,end) in periods.items():
        d = merged[m].loc[start:end]
        
        long_ext  = (d['cot_idx'] > 0.8)
        short_ext = (d['cot_idx'] < 0.2)
        flat      = (~long_ext & ~short_ext)
        
        print(f"\n{name}")
        print(d['cot_idx'].describe()[['mean','std','min','max']])
        print(f"Extreme long:  {long_ext.sum():4d}  ({long_ext.mean():.3f})")
        print(f"Extreme short: {short_ext.sum():4d}  ({short_ext.mean():.3f})")
        print(f"Flat:          {flat.sum():4d}  ({flat.mean():.3f})")
# Out:
# ========================================
# HOGS
#
# 2008-2012
# mean    0.460592
# std     0.317209
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   264  (0.210)
# Extreme short:  287  (0.228)
# Flat:           707  (0.562)
#
# 2013-2016
# mean    0.506565
# std     0.339964
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   262  (0.260)
# Extreme short:  288  (0.286)
# Flat:           456  (0.453)
#
# 2017-2020
# mean    0.527016
# std     0.299708
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   199  (0.198)
# Extreme short:  180  (0.179)
# Flat:           628  (0.624)
#
# 2021-2024
# mean    0.543211
# std     0.340693
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   290  (0.289)
# Extreme short:  226  (0.225)
# Flat:           489  (0.487)
#
# ========================================
# LIVE_CATTLE
#
# 2008-2012
# mean    0.533276
# std     0.331274
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   350  (0.279)
# Extreme short:  276  (0.220)
# Flat:           630  (0.502)
#
# 2013-2016
# mean    0.480894
# std     0.347581
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   259  (0.257)
# Extreme short:  270  (0.268)
# Flat:           477  (0.474)
#
# 2017-2020
# mean    0.495247
# std     0.354016
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   264  (0.262)
# Extreme short:  276  (0.274)
# Flat:           467  (0.464)
#
# 2021-2024
# mean    0.472677
# std     0.316511
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   207  (0.206)
# Extreme short:  254  (0.253)
# Flat:           544  (0.541)
#
# ========================================
# FEEDER_CATTLE
#
# 2008-2012
# mean    0.506207
# std     0.275591
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   199  (0.159)
# Extreme short:  190  (0.151)
# Flat:           866  (0.690)
#
# 2013-2016
# mean    0.539924
# std     0.334028
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   322  (0.323)
# Extreme short:  281  (0.282)
# Flat:           394  (0.395)
#
# 2017-2020
# mean    0.456775
# std     0.345203
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   242  (0.240)
# Extreme short:  340  (0.338)
# Flat:           425  (0.422)
#
# 2021-2024
# mean    0.596849
# std     0.296955
# min     0.000000
# max     1.000000
# Name: cot_idx, dtype: float64
# Extreme long:   286  (0.285)
# Extreme short:  137  (0.136)
# Flat:           582  (0.579)

# %%
markets = ['hogs', 'live_cattle', 'feeder_cattle']

for m in markets:
    print(f"\n{'='*40}\n{m.upper()}")

    for period_name, (start, end) in periods.items():
        d = merged[m].loc[start:end].copy()

        d['signal'] = (d['cot_idx'] > 0.8).astype(int).shift(1)

        on  = d[d['signal']==1]['ret']
        off = d[d['signal']==0]['ret']

        print(period_name)
        print(f"  Avg daily ret on signal: {on.mean():.5f}")
        print(f"  Avg daily ret off signal: {off.mean():.5f}")
        print(f"  N signal days: {len(on)}")
# Out:
# ========================================
# HOGS
# 2008-2012
#   Avg daily ret on signal: 0.00165
#   Avg daily ret off signal: 0.00025
#   N signal days: 264
# 2013-2016
#   Avg daily ret on signal: 0.00137
#   Avg daily ret off signal: -0.00052
#   N signal days: 262
# 2017-2020
#   Avg daily ret on signal: -0.00040
#   Avg daily ret off signal: 0.00082
#   N signal days: 199
# 2021-2024
#   Avg daily ret on signal: 0.00135
#   Avg daily ret off signal: 0.00006
#   N signal days: 290
#
# ========================================
# LIVE_CATTLE
# 2008-2012
#   Avg daily ret on signal: 0.00004
#   Avg daily ret off signal: 0.00039
#   N signal days: 350
# 2013-2016
#   Avg daily ret on signal: -0.00016
#   Avg daily ret off signal: -0.00000
#   N signal days: 259
# 2017-2020
#   Avg daily ret on signal: -0.00001
#   Avg daily ret off signal: 0.00012
#   N signal days: 264
# 2021-2024
#   Avg daily ret on signal: 0.00037
#   Avg daily ret off signal: 0.00064
#   N signal days: 207
#
# ========================================
# FEEDER_CATTLE
# 2008-2012
#   Avg daily ret on signal: 0.00007
#   Avg daily ret off signal: 0.00039
#   N signal days: 199
# 2013-2016
#   Avg daily ret on signal: -0.00026
#   Avg daily ret off signal: -0.00000
#   N signal days: 322
# 2017-2020
#   Avg daily ret on signal: 0.00037
#   Avg daily ret off signal: 0.00007
#   N signal days: 242
# 2021-2024
#   Avg daily ret on signal: 0.00117
#   Avg daily ret off signal: 0.00055
#   N signal days: 286

# %%
markets = ['hogs', 'live_cattle', 'feeder_cattle']

periods = {
    "2000-2007": ('2000','2007'),
    "2013-2019": ('2013','2019'),
    "2020-2024": ('2020','2024')
}

for m in markets:
    print(f"\n{'='*40}\n{m.upper()}")

    for period_name, (start, end) in periods.items():
        mask = merged[m].index >= '2008-01-01'
        d = merged[m][mask].copy()
        d['signal'] = (d['cot_idx'] > 0.8).astype(int)
        d['signal'] = d['signal'].shift(1)
        long_days = d[d['signal'] == 1]['ret']
        
        print(f"Win rate on signal days: {(long_days > 0).mean():.2%}")
        print(f"Avg winner: {long_days[long_days > 0].mean():.4f}")
        print(f"Avg loser: {long_days[long_days < 0].mean():.4f}")
        print(f"Avg W/L ratio: {long_days[long_days > 0].mean() / abs(long_days[long_days < 0].mean()):.3f}")
        print(f"Max single day loss: {long_days.min():.4f}")
        print(f"Max single day gain: {long_days.max():.4f}")
        print(f"\nConsecutive loss analysis:")
        is_loss = (long_days < 0).astype(int)
        consecutive = is_loss * (is_loss.groupby((is_loss != is_loss.shift()).cumsum()).cumcount() + 1)
        print(f"Max consecutive losing days on signal: {consecutive.max()}")
# Out:
# ========================================
# HOGS
# Win rate on signal days: 49.33%
# Avg winner: 0.0165
# Avg loser: -0.0141
# Avg W/L ratio: 1.172
# Max single day loss: -0.1592
# Max single day gain: 0.2666
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 10
# Win rate on signal days: 49.33%
# Avg winner: 0.0165
# Avg loser: -0.0141
# Avg W/L ratio: 1.172
# Max single day loss: -0.1592
# Max single day gain: 0.2666
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 10
# Win rate on signal days: 49.33%
# Avg winner: 0.0165
# Avg loser: -0.0141
# Avg W/L ratio: 1.172
# Max single day loss: -0.1592
# Max single day gain: 0.2666
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 10
#
# ========================================
# LIVE_CATTLE
# Win rate on signal days: 51.26%
# Avg winner: 0.0092
# Avg loser: -0.0098
# Avg W/L ratio: 0.945
# Max single day loss: -0.1448
# Max single day gain: 0.0703
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 8
# Win rate on signal days: 51.26%
# Avg winner: 0.0092
# Avg loser: -0.0098
# Avg W/L ratio: 0.945
# Max single day loss: -0.1448
# Max single day gain: 0.0703
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 8
# Win rate on signal days: 51.26%
# Avg winner: 0.0092
# Avg loser: -0.0098
# Avg W/L ratio: 0.945
# Max single day loss: -0.1448
# Max single day gain: 0.0703
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 8
#
# ========================================
# FEEDER_CATTLE
# Win rate on signal days: 49.20%
# Avg winner: 0.0081
# Avg loser: -0.0072
# Avg W/L ratio: 1.117
# Max single day loss: -0.0661
# Max single day gain: 0.1104
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 8
# Win rate on signal days: 49.20%
# Avg winner: 0.0081
# Avg loser: -0.0072
# Avg W/L ratio: 1.117
# Max single day loss: -0.0661
# Max single day gain: 0.1104
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 8
# Win rate on signal days: 49.20%
# Avg winner: 0.0081
# Avg loser: -0.0072
# Avg W/L ratio: 1.117
# Max single day loss: -0.0661
# Max single day gain: 0.1104
#
# Consecutive loss analysis:
# Max consecutive losing days on signal: 8

# %%
mask = merged['hogs'].index >= '2008-01-01'
d = merged['hogs'][mask].copy()
d['signal'] = (d['cot_idx'] > 0.8).astype(int)
d['signal'] = d['signal'].shift(1)
long_days = d[d['signal'] == 1][['ret']].copy()

long_days['is_loss'] = (long_days['ret'] < 0).astype(int)
long_days['streak'] = long_days['is_loss'] * (
    long_days['is_loss'].groupby(
        (long_days['is_loss'] != long_days['is_loss'].shift()).cumsum()
    ).cumcount() + 1
)

# Find where the worst streaks occurred
streaks = long_days[long_days['streak'] >= 5]
print(streaks[['ret', 'streak']])
# Out:
#                  ret  streak
# Date
# 2009-03-20 -0.004835       5
# 2009-03-23 -0.017814       6
# 2009-04-28 -0.040909       5
# 2009-04-29 -0.045024       6
# 2009-04-30 -0.038875       7
# 2009-06-04 -0.000436       5
# 2009-06-05 -0.001746       6
# 2009-06-26 -0.006570       5
# 2009-07-23 -0.018518       5
# 2009-08-07 -0.044542       6
# 2009-08-10 -0.010246       7
# 2009-08-11 -0.002588       8
# 2009-08-12 -0.008822       9
# 2009-09-22 -0.005484       5
# 2012-05-02 -0.020783       5
# 2015-03-11 -0.028041       5
# 2015-03-12 -0.028460       6
# 2015-03-13 -0.003210       7
# 2015-08-21 -0.029730       5
# 2015-12-08 -0.002704       5
# 2018-03-27 -0.004739       5
# 2018-03-28 -0.014286       6
# 2018-08-01 -0.014315       5
# 2018-08-02 -0.021162       6
# 2018-08-03 -0.008054       7
# 2018-08-06 -0.032479       8
# 2018-08-07 -0.014134       9
# 2018-08-08 -0.017921      10
# 2020-04-02 -0.091463       5
# 2022-04-04 -0.018263       5
# 2022-04-05 -0.017848       6
# 2022-05-06 -0.005837       5
# 2022-05-09 -0.012965       6
# 2023-04-03 -0.009635       5
# 2023-04-04 -0.030862       6
# 2023-05-05 -0.020110       5
# 2023-05-25 -0.026942       5
# 2023-05-26 -0.020283       6
# 2024-02-07 -0.001361       5
# 2024-02-08 -0.001022       6
# 2024-07-08 -0.002225       7
# 2024-07-09 -0.003903       8
# 2024-07-10 -0.009796       9

# %%
for name, df in merged.items():

    d = df.loc['2008-01-01':].copy()

    close_col = next(c for c in d.columns if "Close" in c)
    open_col  = next(c for c in d.columns if "Open" in c)

    d['oc_ret'] = (d[close_col] - d[open_col]) / d[open_col]

    d['signal'] = (d['cot_idx'] > 0.8).astype(int).shift(1)

    long_days = d[d['signal'] == 1]

    print("\n", "="*40)
    print(name.upper())

    print(f"Avg open→close on signal: {long_days['oc_ret'].mean():.5f}")
    print(f"Avg open→close off signal: {d[d['signal']==0]['oc_ret'].mean():.5f}")
    print(f"Win rate: {(long_days['oc_ret'] > 0).mean():.2%}")

    winners = long_days[long_days['oc_ret'] > 0]['oc_ret']
    losers  = long_days[long_days['oc_ret'] < 0]['oc_ret']

    print(f"Avg winner: {winners.mean():.4f}")
    print(f"Avg loser:  {losers.mean():.4f}")
    print(f"Max loss:   {long_days['oc_ret'].min():.4f}")
# Out:
#  ========================================
# CORN
# Avg open→close on signal: 0.00052
# Avg open→close off signal: 0.00014
# Win rate: 51.75%
# Avg winner: 0.0102
# Avg loser:  -0.0103
# Max loss:   -0.0827
#
#  ========================================
# SOY
# Avg open→close on signal: 0.00038
# Avg open→close off signal: 0.00018
# Win rate: 50.66%
# Avg winner: 0.0122
# Avg loser:  -0.0122
# Max loss:   -0.0756
#
#  ========================================
# HOGS
# Avg open→close on signal: -0.00088
# Avg open→close off signal: -0.00037
# Win rate: 46.63%
# Avg winner: 0.0107
# Avg loser:  -0.0112
# Max loss:   -0.0714
#
#  ========================================
# LIVE_CATTLE
# Avg open→close on signal: -0.00017
# Avg open→close off signal: -0.00019
# Win rate: 50.04%
# Avg winner: 0.0074
# Avg loser:  -0.0080
# Max loss:   -0.0664
#
#  ========================================
# FEEDER_CATTLE
# Avg open→close on signal: 0.00000
# Avg open→close off signal: -0.00015
# Win rate: 47.95%
# Avg winner: 0.0065
# Avg loser:  -0.0062
# Max loss:   -0.0320

# %%
for name, df in merged.items():

    d = df.loc['2008-01-01':].copy()

    close_col = next(c for c in d.columns if "Close" in c)

    # close-to-close return
    d['ret'] = d[close_col].pct_change()

    d['signal'] = (d['cot_idx'] > 0.9).astype(int).shift(1)

    long_days = d[d['signal'] == 1]

    print("\n", "="*40)
    print(name.upper())

    print(f"Avg close→close on signal: {long_days['ret'].mean():.5f}")
    print(f"Avg close→close off signal: {d[d['signal']==0]['ret'].mean():.5f}")
    print(f"Win rate: {(long_days['ret'] > 0).mean():.2%}")

    winners = long_days[long_days['ret'] > 0]['ret']
    losers  = long_days[long_days['ret'] < 0]['ret']

    print(f"Avg winner: {winners.mean():.4f}")
    print(f"Avg loser:  {losers.mean():.4f}")
    print(f"Max loss:   {long_days['ret'].min():.4f}")
# Out:
#  ========================================
# CORN
# Avg close→close on signal: -0.00024
# Avg close→close off signal: 0.00021
# Win rate: 49.55%
# Avg winner: 0.0123
# Avg loser:  -0.0129
# Max loss:   -0.2087
#
#  ========================================
# SOY
# Avg close→close on signal: 0.00099
# Avg close→close off signal: 0.00003
# Win rate: 50.45%
# Avg winner: 0.0141
# Avg loser:  -0.0129
# Max loss:   -0.0792
#
#  ========================================
# HOGS
# Avg close→close on signal: 0.00118
# Avg close→close off signal: 0.00026
# Win rate: 48.84%
# Avg winner: 0.0168
# Avg loser:  -0.0139
# Max loss:   -0.1509
#
#  ========================================
# LIVE_CATTLE
# Avg close→close on signal: -0.00022
# Avg close→close off signal: 0.00035
# Win rate: 50.47%
# Avg winner: 0.0098
# Avg loser:  -0.0106
# Max loss:   -0.1448
#
#  ========================================
# FEEDER_CATTLE
# Avg close→close on signal: 0.00026
# Avg close→close off signal: 0.00033
# Win rate: 49.25%
# Avg winner: 0.0082
# Avg loser:  -0.0075
# Max loss:   -0.0350

# %%
mask = merged['hogs'].index >= '2008-01-01'
d = merged['hogs'][mask].copy()

close_col = next(c for c in d.columns if "Close" in c)

# close-to-close return
d['ret'] = d[close_col].pct_change()

d['signal'] = (d['cot_idx'] > 0.8).astype(int)
d['signal'] = d['signal'].shift(1)

d['strat_ret'] = d['signal'] * d['ret']
d['equity'] = (1 + d['strat_ret']).cumprod()

total_ret = d['equity'].iloc[-1] - 1
annual_ret = (1 + total_ret) ** (252 / len(d)) - 1
sharpe = d['strat_ret'].mean() / d['strat_ret'].std() * (252 ** 0.5)
max_dd = (d['equity'] / d['equity'].cummax() - 1).min()

print(f"Annual return: {annual_ret:.2%}")
print(f"Sharpe:        {sharpe:.3f}")
print(f"Max DD:        {max_dd:.2%}")
print(f"Win rate:      {(d[d['signal']==1]['ret'] > 0).mean():.2%}")

d['equity'].plot(title='Hogs COT Long-Only, Close-to-Close')
plt.show()
# Out:
# Annual return: 4.43%
# Sharpe:        0.311
# Max DD:        -47.43%
# Win rate:      49.33%

# %%
mask = merged['live_cattle'].index >= '2008-01-01'
d = merged['live_cattle'][mask].copy()

close_col = next(c for c in d.columns if "Close" in c)

# close-to-close return
d['ret'] = d[close_col].pct_change()

d['signal'] = (d['cot_idx'] > 0.8).astype(int)
d['signal'] = d['signal'].shift(1)

d['strat_ret'] = d['signal'] * d['ret']
d['equity'] = (1 + d['strat_ret']).cumprod()

total_ret = d['equity'].iloc[-1] - 1
annual_ret = (1 + total_ret) ** (252 / len(d)) - 1
sharpe = d['strat_ret'].mean() / d['strat_ret'].std() * (252 ** 0.5)
max_dd = (d['equity'] / d['equity'].cummax() - 1).min()

print(f"Annual return: {annual_ret:.2%}")
print(f"Sharpe:        {sharpe:.3f}")
print(f"Max DD:        {max_dd:.2%}")
print(f"Win rate:      {(d[d['signal']==1]['ret'] > 0).mean():.2%}")

d['equity'].plot(title='Live Cattle COT Long-Only, Close-to-Close')
plt.show()
# Out:
# Annual return: 0.01%
# Sharpe:        0.056
# Max DD:        -27.79%
# Win rate:      51.26%

# %%
mask = merged['feeder_cattle'].index >= '2008-01-01'
d = merged['feeder_cattle'][mask].copy()

close_col = next(c for c in d.columns if "Close" in c)

# close-to-close return
d['ret'] = d[close_col].pct_change()

d['signal'] = (d['cot_idx'] > 0.8).astype(int)
d['signal'] = d['signal'].shift(1)

d['strat_ret'] = d['signal'] * d['ret']
d['equity'] = (1 + d['strat_ret']).cumprod()

total_ret = d['equity'].iloc[-1] - 1
annual_ret = (1 + total_ret) ** (252 / len(d)) - 1
sharpe = d['strat_ret'].mean() / d['strat_ret'].std() * (252 ** 0.5)
max_dd = (d['equity'] / d['equity'].cummax() - 1).min()

print(f"Annual return: {annual_ret:.2%}")
print(f"Sharpe:        {sharpe:.3f}")
print(f"Max DD:        {max_dd:.2%}")
print(f"Win rate:      {(d[d['signal']==1]['ret'] > 0).mean():.2%}")

d['equity'].plot(title='Feeder Cattle COT Long-Only, Close-to-Close')
plt.show()
# Out:
# Annual return: 1.91%
# Sharpe:        0.253
# Max DD:        -28.89%
# Win rate:      49.20%

# %%
# Finding:
# Hog COT extremes (>0.8) show ~0.09% positive next-day drift.
# Effect appears mostly overnight rather than intraday.
# Strategy Sharpe ~0.3 and unstable across regimes → not directly tradable.

# %%
from scipy import stats
markets = ['hogs', 'live_cattle', 'feeder_cattle']
for m in markets:
    print(f'\nMarket:', m)
    d = merged[m].loc['2008':].copy()
    
    close_col = next(c for c in d.columns if "Close" in c)
    d['ret'] = d[close_col].pct_change()
    
    d['signal'] = (d['cot_idx'] > 0.8).astype(int).shift(1)
    
    signal_returns = d[d['signal']==1]['ret'].dropna()
    off_returns = d[d['signal']==0]['ret'].dropna()
    
    t_stat, p_value = stats.ttest_ind(signal_returns, off_returns, equal_var=False)
    
    print("Signal mean:", signal_returns.mean())
    print("Off mean:", off_returns.mean())
    print("t-stat:", t_stat)
    print("p-value:", p_value)
# Out:
# Market: hogs
# Signal mean: 0.00110535955248455
# Off mean: 0.00019565836003249698
# t-stat: 0.9880823740853588
# p-value: 0.32326891736599794
#
# Market: live_cattle
# Signal mean: 9.776565987833378e-05
# Off mean: 0.00030648447565709383
# t-stat: -0.4695954363873805
# p-value: 0.63870797995062
#
# Market: feeder_cattle
# Signal mean: 0.0003723309542260654
# Off mean: 0.00030509617607408547
# t-stat: 0.17166610262179902
# p-value: 0.8637192867794227

# %%
for m in markets: 
    print(f'\nMarket:', m)
    d = merged[m].loc['2008':].copy()
    
    close_col = next(c for c in d.columns if "Close" in c)
    open_col  = next(c for c in d.columns if "Open" in c)
    
    d['cc'] = d[close_col].pct_change()
    d['oc'] = (d[close_col] - d[open_col]) / d[open_col]
    d['overnight'] = d['cc'] - d['oc']
    
    d['signal'] = (d['cot_idx'] > 0.8).astype(int).shift(1)
    
    print("Close→Close:", d[d.signal==1]['cc'].mean())
    print("Open→Close:", d[d.signal==1]['oc'].mean())
    print("Overnight:", d[d.signal==1]['overnight'].mean())
# Out:
# Market: hogs
# Close→Close: 0.00110535955248455
# Open→Close: -0.0008805755063550359
# Overnight: 0.0019859350588395863
#
# Market: live_cattle
# Close→Close: 9.776565987833378e-05
# Open→Close: -0.00016950614000334736
# Overnight: 0.00026727179988168126
#
# Market: feeder_cattle
# Close→Close: 0.0003723309542260654
# Open→Close: 1.6203377786600032e-06
# Overnight: 0.0003707106164474054

# %%
thresholds = [0.7,0.8,0.9,0.95]

for m in markets: 
    print(f'\nMarket:', m)
    d = merged[m].loc['2008':].copy()
    close_col = next(c for c in d.columns if "Close" in c)
    d['ret'] = d[close_col].pct_change()
    
    for t in thresholds:
        
        sig = (d['cot_idx'] > t).astype(int).shift(1)
        
        on = d[sig==1]['ret'].mean()
        off = d[sig==0]['ret'].mean()
        n = sig.sum()
        
        print(f"Threshold {t}:")
        print(f"  mean on: {on:.5f}")
        print(f"  mean off: {off:.5f}")
        print(f"  signals/yr: {n/17:.0f}")
        print()
# Out:
# Market: hogs
# Threshold 0.7:
#   mean on: 0.00104
#   mean off: 0.00009
#   signals/yr: 89
#
# Threshold 0.8:
#   mean on: 0.00111
#   mean off: 0.00020
#   signals/yr: 61
#
# Threshold 0.9:
#   mean on: 0.00118
#   mean off: 0.00026
#   signals/yr: 41
#
# Threshold 0.95:
#   mean on: 0.00084
#   mean off: 0.00035
#   signals/yr: 31
#
#
# Market: live_cattle
# Threshold 0.7:
#   mean on: 0.00017
#   mean off: 0.00029
#   signals/yr: 89
#
# Threshold 0.8:
#   mean on: 0.00010
#   mean off: 0.00031
#   signals/yr: 68
#
# Threshold 0.9:
#   mean on: -0.00022
#   mean off: 0.00035
#   signals/yr: 44
#
# Threshold 0.95:
#   mean on: -0.00047
#   mean off: 0.00036
#   signals/yr: 33
#
#
# Market: feeder_cattle
# Threshold 0.7:
#   mean on: 0.00016
#   mean off: 0.00042
#   signals/yr: 98
#
# Threshold 0.8:
#   mean on: 0.00037
#   mean off: 0.00031
#   signals/yr: 66
#
# Threshold 0.9:
#   mean on: 0.00026
#   mean off: 0.00033
#   signals/yr: 39
#
# Threshold 0.95:
#   mean on: 0.00001
#   mean off: 0.00035
#   signals/yr: 23

# %%
d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()
d['month'] = d.index.month

d['signal'] = (d['cot_idx'] > 0.8).astype(int).shift(1)

for m in range(1,13):

    sub = d[d.month==m]
    on = sub[sub.signal==1]['ret'].mean()
    
    print(f"Month {m}: {on:.5f}")
# Out:
# Month 1: 0.00028
# Month 2: 0.00044
# Month 3: -0.00727
# Month 4: 0.00330
# Month 5: 0.00479
# Month 6: 0.00133
# Month 7: 0.00080
# Month 8: -0.00593
# Month 9: 0.00335
# Month 10: 0.00719
# Month 11: 0.00012
# Month 12: 0.00399

# %%
import numpy as np

signal_returns = d[d.signal==1]['ret'].dropna()

boot = []

for i in range(1000):

    sample = np.random.choice(d['ret'].dropna(), size=len(signal_returns))
    boot.append(sample.mean())

print("Signal mean:", signal_returns.mean())
print("Random mean:", np.mean(boot))
# Out:
# Signal mean: 0.00110535955248455
# Random mean: 0.0003941740485120855

# %%
import numpy as np
import matplotlib.pyplot as plt

d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# signal definition
d['signal'] = (d['cot_idx'] > 0.8).astype(int)

horizon = 20
paths = []

for i in range(len(d) - horizon):
    
    if d['signal'].iloc[i] == 1:
        future = d['ret'].iloc[i+1:i+1+horizon].values
        paths.append(np.cumsum(future))

paths = np.array(paths)

avg_path = paths.mean(axis=0)

plt.plot(avg_path)
plt.axhline(0, linestyle='--')
plt.title("Average return path after COT extreme (hogs)")
plt.xlabel("Days after signal")
plt.ylabel("Cumulative return")
plt.show()

# %%
future20 = []

for i in range(len(d) - 20):
    if d['signal'].iloc[i] == 1:
        r = d['ret'].iloc[i+1:i+21].sum()
        future20.append(r)

future20 = np.array(future20)

print("Mean 20-day return:", future20.mean())
print("Win rate:", (future20 > 0).mean())
print("Number of signals:", len(future20))
# Out:
# Mean 20-day return: 0.032555515498442336
# Win rate: 0.6946050096339114
# Number of signals: 1038

# %%
import numpy as np

d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

d['signal'] = (d['cot_idx'] > 0.8).astype(int)

window = 20
future = []

i = window

while i < len(d) - window:
    
    if d['signal'].iloc[i] == 1:
        
        r = d['ret'].iloc[i+1:i+1+window].sum()
        future.append(r)
        
        i += window   # skip forward to avoid overlap
        
    else:
        i += 1

future = np.array(future)

print("Mean 20-day return:", future.mean())
print("Win rate:", (future > 0).mean())
print("Independent signals:", len(future))
# Out:
# Mean 20-day return: 0.03355972952344162
# Win rate: 0.6716417910447762
# Independent signals: 67

# %%
d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# change in positioning
d['cot_change'] = d['cot_idx'].diff(5)

# signal: extreme AND rising
d['signal2'] = (d['cot_idx'] > 0.8) & (d['cot_change'] > 0)

d['signal2'] = d['signal2'].shift(1)

future = []

for i in range(len(d)-20):

    if d['signal2'].iloc[i]:
        r = d['ret'].iloc[i+1:i+21].sum()
        future.append(r)

import numpy as np
future = np.array(future)

print("Mean 20d return:", future.mean())
print("Win rate:", (future > 0).mean())
print("Signals:", len(future))
# Out:
# Mean 20d return: 0.03271801852213383
# Win rate: 0.7142857142857143
# Signals: 469

# %%
d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# detect entry into extreme
d['signal_cross'] = (d['cot_idx'] > 0.8) & (d['cot_idx'].shift(1) <= 0.8)

future = []

for i in range(len(d)-20):

    if d['signal_cross'].iloc[i]:
        r = d['ret'].iloc[i+1:i+21].sum()
        future.append(r)

import numpy as np
future = np.array(future)

print("Mean 20d return:", future.mean())
print("Win rate:", (future > 0).mean())
print("Signals:", len(future))
# Out:
# Mean 20d return: 0.03415329510520938
# Win rate: 0.6333333333333333
# Signals: 30

# %%
import numpy as np

d = merged['hogs'].loc['2008':].copy()

# extreme regime
d['extreme'] = d['cot_idx'] > 0.8

durations = []
current = 0

for x in d['extreme']:

    if x:
        current += 1
    else:
        if current > 0:
            durations.append(current)
        current = 0

durations = np.array(durations)

print("Number of extreme regimes:", len(durations))
print("Average duration:", durations.mean())
print("Median duration:", np.median(durations))
print("Max duration:", durations.max())
# Out:
# Number of extreme regimes: 30
# Average duration: 34.6
# Median duration: 20.5
# Max duration: 141

# %%
d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# detect entry into bearish extreme
d['signal_short'] = (d['cot_idx'] < 0.2) & (d['cot_idx'].shift(1) >= 0.2)

future = []

for i in range(len(d)-20):
    
    if d['signal_short'].iloc[i]:
        r = d['ret'].iloc[i+1:i+21].sum()
        future.append(r)

import numpy as np
future = np.array(future)

print("Mean 20d return:", future.mean())
print("Win rate:", (future < 0).mean())  # negative returns are "wins" here
print("Signals:", len(future))
# Out:
# Mean 20d return: 0.0358259191520515
# Win rate: 0.34615384615384615
# Signals: 26

# %%
import numpy as np
import matplotlib.pyplot as plt

d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# regime start
d['signal_cross'] = (d['cot_idx'] > 0.8) & (d['cot_idx'].shift(1) <= 0.8)

horizon = 30
paths = []

for i in range(len(d)-horizon):

    if d['signal_cross'].iloc[i]:
        future = d['ret'].iloc[i+1:i+1+horizon].values
        paths.append(np.cumsum(future))

paths = np.array(paths)
avg_path = paths.mean(axis=0)

plt.plot(avg_path)
plt.axhline(0, linestyle='--')
plt.title("Average path after regime start")
plt.xlabel("Days after regime start")
plt.ylabel("Cumulative return")
plt.show()

# %%
d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# speculator extreme long
d['spec_long'] = (d['spec_idx'] > 0.8) & (d['spec_idx'].shift(1) <= 0.8)

future = []

for i in range(len(d)-20):

    if d['spec_long'].iloc[i]:
        r = d['ret'].iloc[i+1:i+21].sum()
        future.append(r)

future = np.array(future)

print("Mean 20d return:", future.mean())
print("Win rate:", (future < 0).mean())
print("Signals:", len(future))
# Out:
# Mean 20d return: 0.02354205900353446
# Win rate: 0.45161290322580644
# Signals: 31

# %%
import pandas as pd

d = merged['hogs'].loc['2008':].copy()

# regime start
d['signal_cross'] = (d['cot_idx'] > 0.8) & (d['cot_idx'].shift(1) <= 0.8)

years = d[d['signal_cross']].index.year

print(years.value_counts().sort_index())
# Out:
# Date
# 2008    1
# 2009    3
# 2010    1
# 2011    1
# 2012    1
# 2013    1
# 2014    3
# 2015    2
# 2016    1
# 2017    1
# 2018    1
# 2019    1
# 2020    3
# 2021    1
# 2022    4
# 2023    3
# 2024    1
# 2025    1
# Name: count, dtype: int64

# %%
d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

d['signal_cross'] = (d['cot_idx'] > 0.8) & (d['cot_idx'].shift(1) <= 0.8)

trades = []

for i in range(len(d)-20):

    if d['signal_cross'].iloc[i]:

        r = d['ret'].iloc[i+1:i+21].sum()
        trades.append(r)

import numpy as np
trades = np.array(trades)

print("Trades:", len(trades))
print("Mean return:", trades.mean())
print("Win rate:", (trades>0).mean())
print("Best trade:", trades.max())
print("Worst trade:", trades.min())
# Out:
# Trades: 30
# Mean return: 0.03415329510520938
# Win rate: 0.6333333333333333
# Best trade: 0.1861998644505375
# Worst trade: -0.14796308682325043

# %%
equity = np.cumprod(1 + trades)

import matplotlib.pyplot as plt

plt.plot(equity)
plt.title("Equity curve of regime trades")
plt.show()

# %%
import numpy as np

sorted_trades = np.sort(trades)

print("Worst 5:", sorted_trades[:5])
print("Best 5:", sorted_trades[-5:])
print("Median trade:", np.median(trades))
# Out:
# Worst 5: [-0.14796309 -0.12923026 -0.12732271 -0.06422136 -0.05167502]
# Best 5: [0.12236636 0.15663852 0.16662664 0.18043304 0.18619986]
# Median trade: 0.021437732443339907

# %%
import numpy as np
import matplotlib.pyplot as plt

d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)
d['ret'] = d[close_col].pct_change()

# regime start
d['signal_cross'] = (d['cot_idx'] > 0.8) & (d['cot_idx'].shift(1) <= 0.8)

horizon = 30
paths = []

for i in range(len(d)-horizon):

    if d['signal_cross'].iloc[i]:
        future = d['ret'].iloc[i+1:i+1+horizon].values
        paths.append(np.cumsum(future))

paths = np.array(paths)

plt.figure(figsize=(10,6))

# plot each trade
for p in paths:
    plt.plot(p, alpha=0.35)

# average path
avg_path = paths.mean(axis=0)
plt.plot(avg_path, linewidth=3, label="Average path")

plt.axhline(0, linestyle='--')
plt.title("All regime return paths (30 trades)")
plt.xlabel("Days after regime start")
plt.ylabel("Cumulative return")
plt.legend()
plt.show()

# %%
horizon = 30
check_day = 20

trades_rule = []

for i in range(len(d)-horizon):

    if d['signal_cross'].iloc[i]:

        path = d['ret'].iloc[i+1:i+1+horizon].cumsum()

        # early exit rule
        if path.iloc[check_day] <= 0:
            trades_rule.append(path.iloc[check_day])
        else:
            trades_rule.append(path.iloc[-1])

import numpy as np
trades_rule = np.array(trades_rule)

print("Trades:", len(trades_rule))
print("Mean:", trades_rule.mean())
print("Median:", np.median(trades_rule))
print("Win rate:", (trades_rule>0).mean())
# Out:
# Trades: 30
# Mean: 0.035951685980074546
# Median: 0.04873105929346799
# Win rate: 0.5333333333333333

# %%
import matplotlib.pyplot as plt

d = merged['hogs'].loc['2008':].copy()

close_col = next(c for c in d.columns if "Close" in c)

# regime condition
d['extreme'] = d['cot_idx'] > 0.8

regimes = []
in_regime = False
start = None

for i in range(len(d)):

    if d['extreme'].iloc[i] and not in_regime:
        start = d.index[i]
        in_regime = True

    elif not d['extreme'].iloc[i] and in_regime:
        end = d.index[i]
        regimes.append((start, end))
        in_regime = False

# handle regime lasting to end of dataset
if in_regime:
    regimes.append((start, d.index[-1]))

plt.figure(figsize=(12,6))
plt.plot(d.index, d[close_col], label="Hogs price")

for s, e in regimes:
    plt.axvspan(s, e, color='green', alpha=0.2)

plt.title("Lean hog price with COT extreme regimes")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

d = merged['hogs'].copy()

# find correct close column
close_col = [c for c in d.columns if "Close" in c][0]

# signal definition
d['signal'] = (d['cot_idx'] > 0.8).astype(int)

# regime start
d['start'] = (d['signal'] == 1) & (d['signal'].shift(1) == 0)

starts = d.index[d['start']]

horizon = 40
paths = []

for t in starts:
    
    loc = d.index.get_loc(t)

    if loc + horizon >= len(d):
        continue

    window = d[close_col].iloc[loc:loc+horizon]
    ret = window / window.iloc[0] - 1
    paths.append(ret.values)

paths = np.array(paths)

mean_path = paths.mean(axis=0)
median_path = np.median(paths, axis=0)

plt.figure(figsize=(8,5))
plt.plot(mean_path, label="Mean")
plt.plot(median_path, label="Median")
plt.axhline(0)
plt.title("Forward Returns After COT Extreme (Hogs)")
plt.xlabel("Days After Signal")
plt.ylabel("Return")
plt.legend()
plt.show()

print("Independent signals:", len(paths))
# Out:
# Independent signals: 41

# %%
import numpy as np
import matplotlib.pyplot as plt

d = merged['hogs'].copy()

close_col = [c for c in d.columns if "Close" in c][0]

d['signal'] = (d['cot_idx'] > 0.8).astype(int)
d['start'] = (d['signal'] == 1) & (d['signal'].shift(1) == 0)

starts = d.index[d['start']]

horizon = 40
paths_before = []

for t in starts:

    loc = d.index.get_loc(t)

    if loc - horizon < 0:
        continue

    window = d[close_col].iloc[loc-horizon:loc]
    ret = window / window.iloc[-1] - 1
    paths_before.append(ret.values)

paths_before = np.array(paths_before)

mean_before = paths_before.mean(axis=0)
median_before = np.median(paths_before, axis=0)

plt.figure(figsize=(8,5))
plt.plot(mean_before, label="Mean")
plt.plot(median_before, label="Median")
plt.axhline(0)

plt.title("Returns BEFORE COT Extreme (Hogs)")
plt.xlabel("Days Before Signal")
plt.ylabel("Return")
plt.legend()

plt.show()

print("Signals used:", len(paths_before))
# Out:
# Signals used: 40

# %%
d = merged['hogs'].copy()

close_col = [c for c in d.columns if "Close" in c][0]

# daily return
d['ret'] = d[close_col].pct_change()

# 20-day return BEFORE signal
d['ret20'] = d[close_col].pct_change(20)

# COT signal
d['signal'] = (d['cot_idx'] > 0.8)

# ensure boolean
prev_signal = d['signal'].shift(1).fillna(False)

d['start'] = d['signal'] & (~prev_signal)

horizon = 20

def forward_return(df, horizon):
    return df[close_col].shift(-horizon) / df[close_col] - 1

d['fwd20'] = forward_return(d, horizon)

signals = d[d['start']].copy()

print("All signals:", signals['fwd20'].mean())

for dd in [-0.05, -0.10, -0.15]:
    subset = signals[signals['ret20'] < dd]
    print(f"\nPrior 20d return < {dd}")
    print("signals:", len(subset))
    print("mean forward:", subset['fwd20'].mean())
# Out:
# All signals: 0.03416088001787987
#
# Prior 20d return < -0.05
# signals: 449
# mean forward: 0.04408986883236869
#
# Prior 20d return < -0.1
# signals: 233
# mean forward: 0.044014614551415296
#
# Prior 20d return < -0.15
# signals: 106
# mean forward: 0.05431770407084332

# %%
d = merged['hogs'].copy()

close_col = [c for c in d.columns if "Close" in c][0]

# 20-day return BEFORE today
d['ret20'] = d[close_col].pct_change(20)

# 20-day return AFTER today
d['fwd20'] = d[close_col].shift(-20) / d[close_col] - 1

print("All days:", d['fwd20'].mean())

for dd in [-0.05, -0.10, -0.15]:
    
    subset = d[d['ret20'] < dd]
    
    print(f"\nPrior 20d return < {dd}")
    print("days:", len(subset))
    print("mean forward:", subset['fwd20'].mean())
# Out:
# All days: 0.00807124715510284
#
# Prior 20d return < -0.05
# days: 1646
# mean forward: 0.02164285208250882
#
# Prior 20d return < -0.1
# days: 903
# mean forward: 0.030599564965224518
#
# Prior 20d return < -0.15
# days: 465
# mean forward: 0.04655899297364444

# %%
import numpy as np
import matplotlib.pyplot as plt

d = merged['hogs'].copy()

close_col = [c for c in d.columns if "Close" in c][0]

# prior 20-day drawdown
d['ret20'] = d[close_col].pct_change(20)

# COT signal
d['cot_sig'] = d['cot_idx'] > 0.8

drawdown = d['ret20'] < -0.05
cot_drawdown = drawdown & d['cot_sig']

horizon = 40

def forward_paths(df, mask, horizon):
    paths = []

    idx = df.index[mask]

    for t in idx:
        loc = df.index.get_loc(t)

        if loc + horizon >= len(df):
            continue

        window = df[close_col].iloc[loc:loc+horizon]
        ret = window / window.iloc[0] - 1
        paths.append(ret.values)

    return np.array(paths)

paths_dd = forward_paths(d, drawdown, horizon)
paths_cot = forward_paths(d, cot_drawdown, horizon)

mean_dd = paths_dd.mean(axis=0)
mean_cot = paths_cot.mean(axis=0)

median_dd = np.median(paths_dd, axis=0)
median_cot = np.median(paths_cot, axis=0)

plt.figure(figsize=(9,5))

plt.plot(mean_dd, label="Drawdown only (mean)")
plt.plot(mean_cot, label="Drawdown + COT (mean)")

plt.plot(median_dd, "--", label="Drawdown only (median)")
plt.plot(median_cot, "--", label="Drawdown + COT (median)")

plt.axhline(0)

plt.title("Forward Returns After Hog Selloffs")
plt.xlabel("Days After Event")
plt.ylabel("Return")

plt.legend()
plt.show()

print("Drawdown events:", len(paths_dd))
print("Drawdown + COT events:", len(paths_cot))
# Out:
# Drawdown events: 1646
# Drawdown + COT events: 449

# %%
trade_returns = []
trade_dates = []

entry_delay = 5
hold = 20

i = 0

d['ret60'] = d[close_col].pct_change(60)

while i < len(d):

    # check signal + drawdown condition
    if d['start'].iloc[i] and d['ret60'].iloc[i] < -0.1:

        signal_loc = i
        entry_loc = signal_loc + entry_delay
        exit_loc  = entry_loc + hold

        if exit_loc >= len(d):
            break

        entry_price = d[close_col].iloc[entry_loc]
        exit_price  = d[close_col].iloc[exit_loc]

        trade_returns.append(exit_price / entry_price - 1)
        trade_dates.append(d.index[entry_loc])

        # skip forward to exit so trades can't overlap
        i = exit_loc
        continue

    i += 1

# %%
import numpy as np

trades = np.array(trade_returns)

mean = trades.mean()
std = trades.std()

# scale to annual assuming 20-day holding
sharpe = (mean / std) * np.sqrt(252 / hold)

print("Trades:", len(trades))
print("Mean:", mean)
print("Median:", np.median(trades))
print("Win rate:", (trades > 0).mean())
print("Sharpe:", sharpe)
# Out:
# Trades: 14
# Mean: 0.07979085285585431
# Median: 0.07314885475132138
# Win rate: 0.7857142857142857
# Sharpe: 2.4023292210884613

# %%
import pandas as pd

trade_df = pd.DataFrame({
    "date": trade_dates,
    "ret": trade_returns
})

trade_df["year"] = trade_df["date"].dt.year

print(trade_df["year"].value_counts().sort_index())
# Out:
# year
# 2001    2
# 2002    2
# 2003    3
# 2005    3
# 2006    2
# 2008    1
# 2009    5
# 2010    1
# 2011    1
# 2012    1
# 2014    2
# 2015    4
# 2016    1
# 2018    4
# 2019    1
# 2020    2
# 2022    2
# 2023    4
# 2024    1
# Name: count, dtype: int64

# %%
equity = (1 + pd.Series(trades)).cumprod()
equity.plot(title="Hog COT Reversal Strategy")
# Out:
# <Axes: title={'center': 'Hog COT Reversal Strategy'}>

# %%
dd_windows = [5, 10, 15, 20, 25, 30, 40, 60]
dd_thresholds = [-0.01, -0.02, -0.03, -0.05, -0.08, -0.10]

# %%
import numpy as np
import pandas as pd

results = []

for w in dd_windows:

    d[f"ret{w}"] = d[close_col].pct_change(w)

    for dd in dd_thresholds:

        trade_returns = []
        i = 0

        while i < len(d):

            if d['start'].iloc[i] and d[f"ret{w}"].iloc[i] < dd:

                entry_loc = i + entry_delay
                exit_loc  = entry_loc + hold

                if exit_loc >= len(d):
                    break

                entry_price = d[close_col].iloc[entry_loc]
                exit_price  = d[close_col].iloc[exit_loc]

                trade_returns.append(exit_price / entry_price - 1)

                i = exit_loc
                continue

            i += 1

        if len(trade_returns) > 5:

            r = np.array(trade_returns)

            sharpe = (r.mean() / r.std()) * np.sqrt(252 / hold)

        else:
            sharpe = np.nan

        results.append({
            "window": w,
            "drawdown": dd,
            "sharpe": sharpe,
            "trades": len(trade_returns)
        })

# %%
df = pd.DataFrame(results)

heat = df.pivot(index="drawdown", columns="window", values="sharpe")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(heat, annot=True, fmt=".2f", cmap="RdYlGn", center=0)
plt.title("Sharpe vs Drawdown Window / Threshold")
plt.show()
